# %% [markdown]
# ## Titanic playground
#
# Titanic dataset. Mоже да се изтегли от тук:
# https://www.kaggle.com/wsj/college-salaries
#
# #### Започваме
#
# Инсталираме първоначалните библиотеки:

# %%
# !pip install numpy scipy matplotlib ipython scikit-learn pandas pillow mglearn

# %% [markdown]
# Импортваме по-горе инсталираните библиотеки:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import mglearn

from IPython.display import display

# %matplotlib inline

# %% [markdown]
# Следващата стъпка е зараждането на dataset-а. Ще използваме pandas.
#
# Зареждаме данните:

# %%
pd.read_csv('data/titanic/train.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
original = pd.read_csv('data/titanic/train.csv', index_col='PassengerId')

# %%
original
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
original.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
original.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
original.isnull().sum().sort_values()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Embarked      2
# Age         177
# Cabin       687
# dtype: int64

# %%
sns.countplot("Survived", data=original)

# %%
sns.countplot("Sex", hue="Survived", data=original)

# %%
pd.crosstab(original.Pclass, original.Survived, margins=True).style.background_gradient(cmap="summer_r")
# Out:
#         <style  type="text/css" >
#
#
#             #T_7d2c54e4_cec4_11e7_aa88_0242ac110002row0_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_7d2c54e4_cec4_11e7_aa88_0242ac110002row0_col1 {
#
#                 background-color:  #cee666;
#
#             }
#
#             #T_7d2c54e4_cec4_11e7_aa88_0242ac110002row0_col2 {
#
#                 background-color:  #f4fa66;
#
#             }
#
#             #T_7d2c54e4_cec4_11e7_aa88_0242ac110002row1_col0 {
#
#                 background-color:  #f6fa66;
#
#             }
#
#             #T_7d2c54e4_cec4_11e7_aa88_0242ac110002row1_col1 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_7d2c54e4_cec4_11e7_aa88_0242ac110002row1_col2 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_7d2c54e4_cec4_11e7_aa88_0242ac110002row2_col0 {
#
#                 background-color:  #60b066;
#
#             }
#
# ...

# %%
sns.countplot("Pclass", hue="Survived", data=original)

# %%
sns.factorplot("Pclass", "Survived", hue="Sex", data=original)

# %%
sns.violinplot("Pclass", "Age", hue="Survived", data=original, split=True)

# %%
sns.violinplot("Sex", "Age", hue="Survived", data=original, split=True)

# %%
original.Name.str.extract('([A-Za-z]+)\.').value_counts()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Mlle          2
# Major         2
# Col           2
# Sir           1
# Mme           1
# Countess      1
# Lady          1
# Capt          1
# Don           1
# Ms            1
# Jonkheer      1
# Name: Name, dtype: int64

# %%
pd.crosstab(original.Embarked, original.Survived, margins=True).style.background_gradient(cmap="summer_r")
# Out:
#         <style  type="text/css" >
#
#
#             #T_16e0c4fc_cec6_11e7_aa88_0242ac110002row0_col0 {
#
#                 background-color:  #f1f866;
#
#             }
#
#             #T_16e0c4fc_cec6_11e7_aa88_0242ac110002row0_col1 {
#
#                 background-color:  #cbe566;
#
#             }
#
#             #T_16e0c4fc_cec6_11e7_aa88_0242ac110002row0_col2 {
#
#                 background-color:  #e3f166;
#
#             }
#
#             #T_16e0c4fc_cec6_11e7_aa88_0242ac110002row1_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_16e0c4fc_cec6_11e7_aa88_0242ac110002row1_col1 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_16e0c4fc_cec6_11e7_aa88_0242ac110002row1_col2 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_16e0c4fc_cec6_11e7_aa88_0242ac110002row2_col0 {
#
#                 background-color:  #3e9e66;
#
#             }
#
# ...

# %%
sns.factorplot("Embarked", "Survived", data=original)
